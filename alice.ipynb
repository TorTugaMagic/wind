# %%
# !wsl.exe -v -l # para ver los distros instalados en tu computadoras.

# %%
wsl.exe -v -l # para ver los distros instalados en tu computadoras.

# %%
wsl --install -d <Distribution Name>  # para ver los distros instalados en tu computadoras.

# %%
# !wsl.exe -l -o #Desde la linea de comando de linux, para ver los sistemas operativos disponibles

# %%
print("hola")
